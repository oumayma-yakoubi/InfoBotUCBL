# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
requirements_path = '/content/drive/MyDrive/CC2-LLM/requirements.txt'

# %%
# !pip install -r {requirements_path}
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (0.3.14)
# Collecting langchain_community (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 2))
#   Downloading langchain_community-0.3.14-py3-none-any.whl.metadata (2.9 kB)
# Collecting pypdf (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 3))
#   Downloading pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting langchain-huggingface (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4))
#   Downloading langchain_huggingface-0.1.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting langgraph (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 5))
#   Downloading langgraph-0.2.62-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 6)) (4.12.3)
# Collecting streamlit (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7))
#   Downloading streamlit-1.41.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting PyPDF2 (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 8))
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting pdfplumber (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 9))
#   Downloading pdfplumber-0.11.5-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 1.8 MB/s eta 0:00:00
# Collecting tiktoken (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 10))
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting scrapegraphai (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading scrapegraphai-1.35.0-py3-none-any.whl.metadata (13 kB)
# Collecting chromadb (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading chromadb-0.6.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting langchain_groq (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 13))
#   Downloading langchain_groq-0.2.3-py3-none-any.whl.metadata (3.0 kB)
# Collecting markdownify (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 14))
#   Downloading markdownify-0.14.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting langchain_experimental (from -r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 15))
#   Downloading langchain_experimental-0.3.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (3.11.11)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (0.3.29)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (0.3.5)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (0.2.10)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (2.10.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (9.0.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 2))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain_community->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 2))
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 2))
#   Downloading pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (0.27.1)
# Requirement already satisfied: sentence-transformers>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (3.3.1)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (0.21.0)
# Requirement already satisfied: transformers>=4.39.0 in /usr/local/lib/python3.10/dist-packages (from langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (4.47.1)
# Collecting langgraph-checkpoint<3.0.0,>=2.0.4 (from langgraph->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 5))
#   Downloading langgraph_checkpoint-2.0.9-py3-none-any.whl.metadata (4.6 kB)
# Collecting langgraph-sdk<0.2.0,>=0.1.42 (from langgraph->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 5))
#   Downloading langgraph_sdk-0.1.51-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 6)) (2.6)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (8.1.8)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (17.0.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (13.9.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (0.10.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7))
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (3.1.44)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7))
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (6.3.3)
# Collecting pdfminer.six==20231228 (from pdfplumber->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 9))
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 9))
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 9)) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 9)) (43.0.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 10)) (2024.11.6)
# Collecting free-proxy>=1.1.1 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading free_proxy-1.1.3.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting googlesearch-python>=1.2.5 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading googlesearch_python-1.2.5-py3-none-any.whl.metadata (2.9 kB)
# Collecting html2text>=2024.2.26 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading html2text-2024.2.26.tar.gz (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jsonschema>=4.23.0 in /usr/local/lib/python3.10/dist-packages (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11)) (4.23.0)
# Collecting langchain-aws>=0.1.3 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading langchain_aws-0.2.10-py3-none-any.whl.metadata (3.2 kB)
# Collecting langchain-mistralai>=0.1.12 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading langchain_mistralai-0.2.4-py3-none-any.whl.metadata (2.5 kB)
# Collecting langchain-ollama>=0.1.3 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading langchain_ollama-0.2.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting langchain-openai>=0.1.22 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading langchain_openai-0.3.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting minify-html>=0.15.0 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading minify_html-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (17 kB)
# Collecting playwright>=1.43.0 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading playwright-1.49.1-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Collecting python-dotenv>=1.0.1 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting semchunk>=2.2.0 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading semchunk-3.0.1-py3-none-any.whl.metadata (12 kB)
# Collecting simpleeval>=1.0.0 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading simpleeval-1.0.3-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: tqdm>=4.66.4 in /usr/local/lib/python3.10/dist-packages (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11)) (4.67.1)
# Collecting undetected-playwright>=0.3.0 (from scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading undetected_playwright-0.3.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting build>=1.0.3 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting posthog>=2.4.0 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading posthog-3.7.5-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (1.29.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (1.29.0)
# Collecting pypika>=0.48.9 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting overrides>=7.3.1 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (1.69.0)
# Collecting bcrypt>=4.0.1 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.8 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (0.15.1)
# Collecting kubernetes>=28.1.0 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (3.10.13)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (0.28.1)
# Collecting groq<1,>=0.4.1 (from langchain_groq->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 13))
#   Downloading groq-0.15.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: six<2,>=1.15 in /usr/local/lib/python3.10/dist-packages (from markdownify->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 14)) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (1.18.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (3.1.5)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (1.21.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (2.2.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 2))
#   Downloading marshmallow-3.25.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 2))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi>=0.95.2->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from free-proxy>=1.1.1->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11)) (5.3.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (4.0.12)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 13)) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 13)) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain_groq->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 13)) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (2024.10.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.23.0->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.23.0->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.23.0->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11)) (0.22.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (2.3.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting boto3>=1.35.74 (from langchain-aws>=0.1.3->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading boto3-1.35.97-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.29->langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (1.33)
# Collecting ollama<1,>=0.4.4 (from langchain-ollama>=0.1.3->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading ollama-0.4.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /usr/local/lib/python3.10/dist-packages (from langchain-openai>=0.1.22->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11)) (1.59.4)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from langgraph-checkpoint<3.0.0,>=2.0.4->langgraph->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.17->langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (1.0.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (24.12.23)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (1.66.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.29.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.29.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading opentelemetry_proto-1.29.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf<6,>=3.20 (from streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7))
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading opentelemetry_instrumentation-0.50b0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (0.50b0)
# Collecting opentelemetry-util-http==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading opentelemetry_util_http-0.50b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (1.17.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (2024.2)
# Requirement already satisfied: greenlet==3.1.1 in /usr/local/lib/python3.10/dist-packages (from playwright>=1.43.0->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11)) (3.1.1)
# Collecting pyee==12.0.0 (from playwright>=1.43.0->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading pyee-12.0.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (2.18.0)
# Collecting mpire[dill] (from semchunk>=2.2.0->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading mpire-2.10.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.6.0->langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.39.0->langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading watchfiles-1.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (14.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain_groq->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 13)) (1.2.2)
# Collecting botocore<1.36.0,>=1.35.97 (from boto3>=1.35.74->langchain-aws>=0.1.3->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading botocore-1.35.97-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.35.74->langchain-aws>=0.1.3->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.35.74->langchain-aws>=0.1.3->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading s3transfer-0.10.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 9)) (1.17.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (4.9)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 7)) (0.1.2)
# Collecting httpx>=0.27.0 (from chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.58.1->langchain-openai>=0.1.22->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11)) (0.8.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (1.3.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 2))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting multiprocess (from mpire[dill]->semchunk>=2.2.0->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 9)) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 12)) (0.6.1)
# Collecting dill>=0.3.9 (from multiprocess->mpire[dill]->semchunk>=2.2.0->scrapegraphai->-r /content/drive/MyDrive/CC2-LLM/requirements.txt (line 11))
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Downloading langchain_community-0.3.14-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 36.0 MB/s eta 0:00:00
# Downloading pypdf-5.1.0-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 20.9 MB/s eta 0:00:00
# Downloading langchain_huggingface-0.1.2-py3-none-any.whl (21 kB)
# Downloading langgraph-0.2.62-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.2/138.2 kB 11.1 MB/s eta 0:00:00
# Downloading streamlit-1.41.1-py2.py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 90.4 MB/s eta 0:00:00
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 14.7 MB/s eta 0:00:00
# Downloading pdfplumber-0.11.5-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.2 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 53.1 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.4 MB/s eta 0:00:00
# Downloading scrapegraphai-1.35.0-py3-none-any.whl (173 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.0/173.0 kB 12.8 MB/s eta 0:00:00
# Downloading chromadb-0.6.2-py3-none-any.whl (606 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 606.2/606.2 kB 30.7 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.1 MB/s eta 0:00:00
# Downloading langchain_groq-0.2.3-py3-none-any.whl (14 kB)
# Downloading markdownify-0.14.1-py3-none-any.whl (11 kB)
# Downloading langchain_experimental-0.3.4-py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 kB 14.2 MB/s eta 0:00:00
# Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 18.1 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 7.0 MB/s eta 0:00:00
# Downloading googlesearch_python-1.2.5-py3-none-any.whl (4.8 kB)
# Downloading groq-0.15.0-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 8.7 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 61.1 MB/s eta 0:00:00
# Downloading langchain_aws-0.2.10-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 7.7 MB/s eta 0:00:00
# Downloading langchain_mistralai-0.2.4-py3-none-any.whl (15 kB)
# Downloading langchain_ollama-0.2.2-py3-none-any.whl (18 kB)
# Downloading langchain_openai-0.3.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 3.6 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-2.0.9-py3-none-any.whl (37 kB)
# Downloading langgraph_sdk-0.1.51-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 3.0 MB/s eta 0:00:00
# Downloading minify_html-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.3 MB/s eta 0:00:00
# Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.3 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 84.1 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.29.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 3.8 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.50b0-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.50b0-py3-none-any.whl (6.9 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading playwright-1.49.1-py3-none-manylinux1_x86_64.whl (44.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 MB 20.7 MB/s eta 0:00:00
# Downloading pyee-12.0.0-py3-none-any.whl (14 kB)
# Downloading posthog-3.7.5-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 3.8 MB/s eta 0:00:00
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 20.0 MB/s eta 0:00:00
# Downloading pydantic_settings-2.7.1-py3-none-any.whl (29 kB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 88.6 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 77.2 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading semchunk-3.0.1-py3-none-any.whl (12 kB)
# Downloading simpleeval-1.0.3-py3-none-any.whl (15 kB)
# Downloading undetected_playwright-0.3.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 3.9 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.4 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.5 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading boto3-1.35.97-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 10.2 MB/s eta 0:00:00
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 25.9 MB/s eta 0:00:00
# Downloading marshmallow-3.25.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.2 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading ollama-0.4.5-py3-none-any.whl (13 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.5 MB/s eta 0:00:00
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.1 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 72.4 MB/s eta 0:00:00
# Downloading watchfiles-1.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 kB 25.8 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.0 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading botocore-1.35.97-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 90.3 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 2.9 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading s3transfer-0.10.4-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 5.8 MB/s eta 0:00:00
# Downloading mpire-2.10.2-py3-none-any.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.8/272.8 kB 18.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.17-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.5 MB/s eta 0:00:00
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 9.4 MB/s eta 0:00:00
# Building wheels for collected packages: free-proxy, html2text, pypika
#   Building wheel for free-proxy (setup.py) ... done
#   Created wheel for free-proxy: filename=free_proxy-1.1.3-py3-none-any.whl size=6096 sha256=c1aa321eeb30cbb20b510fa27a602955de26b5b337b0188f773118fd9246c4a2
#   Stored in directory: /root/.cache/pip/wheels/95/45/0e/36fc27d383f76ec4e6f876c6584102b5ab6146ae535735a1ea
#   Building wheel for html2text (setup.py) ... done
#   Created wheel for html2text: filename=html2text-2024.2.26-py3-none-any.whl size=33111 sha256=79d6e8fa6754a1089eae67cd4906714c2677ec752ecfec45fccca97c84c13748
#   Stored in directory: /root/.cache/pip/wheels/f3/96/6d/a7eba8f80d31cbd188a2787b81514d82fc5ae6943c44777659
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53771 sha256=a1c9ce730a6111fd90d392a38a7204f369d43941850b0fb4fad1a1eecb65017b
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built free-proxy html2text pypika
# Installing collected packages: pypika, monotonic, minify-html, durationpy, watchdog, uvloop, uvicorn, simpleeval, python-dotenv, pyproject_hooks, pypdfium2, PyPDF2, pypdf, pyee, protobuf, overrides, opentelemetry-util-http, mypy-extensions, mpire, mmh3, marshmallow, jmespath, humanfriendly, httpx-sse, httptools, html2text, dill, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, typing-inspect, tiktoken, starlette, pydeck, posthog, playwright, opentelemetry-proto, multiprocess, markdownify, httpx, googlesearch-python, free-proxy, coloredlogs, build, botocore, undetected-playwright, s3transfer, pydantic-settings, pdfminer.six, opentelemetry-exporter-otlp-proto-common, onnxruntime, ollama, langgraph-sdk, kubernetes, groq, fastapi, dataclasses-json, semchunk, pdfplumber, opentelemetry-instrumentation, boto3, streamlit, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, langgraph-checkpoint, langchain-openai, langchain-ollama, langchain-mistralai, langchain_groq, langchain-aws, opentelemetry-instrumentation-fastapi, langgraph, langchain-huggingface, langchain_community, chromadb, scrapegraphai, langchain_experimental
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.3 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.29.3 which is incompatible.
# Successfully installed PyPDF2-3.0.1 asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.1 boto3-1.35.97 botocore-1.35.97 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.6.2 coloredlogs-15.0.1 dataclasses-json-0.6.7 dill-0.3.9 durationpy-0.9 fastapi-0.115.6 free-proxy-1.1.3 googlesearch-python-1.2.5 groq-0.15.0 html2text-2024.2.26 httptools-0.6.4 httpx-0.27.2 httpx-sse-0.4.0 humanfriendly-10.0 jmespath-1.0.1 kubernetes-31.0.0 langchain-aws-0.2.10 langchain-huggingface-0.1.2 langchain-mistralai-0.2.4 langchain-ollama-0.2.2 langchain-openai-0.3.0 langchain_community-0.3.14 langchain_experimental-0.3.4 langchain_groq-0.2.3 langgraph-0.2.62 langgraph-checkpoint-2.0.9 langgraph-sdk-0.1.51 markdownify-0.14.1 marshmallow-3.25.0 minify-html-0.15.0 mmh3-5.0.1 monotonic-1.6 mpire-2.10.2 multiprocess-0.70.17 mypy-extensions-1.0.0 ollama-0.4.5 onnxruntime-1.20.1 opentelemetry-exporter-otlp-proto-common-1.29.0 opentelemetry-exporter-otlp-proto-grpc-1.29.0 opentelemetry-instrumentation-0.50b0 opentelemetry-instrumentation-asgi-0.50b0 opentelemetry-instrumentation-fastapi-0.50b0 opentelemetry-proto-1.29.0 opentelemetry-util-http-0.50b0 overrides-7.7.0 pdfminer.six-20231228 pdfplumber-0.11.5 playwright-1.49.1 posthog-3.7.5 protobuf-5.29.3 pydantic-settings-2.7.1 pydeck-0.9.1 pyee-12.0.0 pypdf-5.1.0 pypdfium2-4.30.1 pypika-0.48.9 pyproject_hooks-1.2.0 python-dotenv-1.0.1 s3transfer-0.10.4 scrapegraphai-1.35.0 semchunk-3.0.1 simpleeval-1.0.3 starlette-0.41.3 streamlit-1.41.1 tiktoken-0.8.0 typing-inspect-0.9.0 undetected-playwright-0.3.0 uvicorn-0.34.0 uvloop-0.21.0 watchdog-6.0.0 watchfiles-1.0.4

# %%
! wget -q -O - ipv4.canhazip.com
# Out:
# 35.229.251.151

# %%
# !streamlit run /content/drive/MyDrive/CC2-LLM/app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠙⠹⠸⠼⠴⠦
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.229.251.151:8501
#
# ⠧⠇your url is: https://slick-hats-dress.loca.lt
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# USER_AGENT n'existait pas. Il a été créé avec la valeur : MyApp
# 2025-01-11 17:36:29.207314: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-11 17:36:29.236476: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-11 17:36:29.249425: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-11 17:36:29.281293: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-11 17:36:31.179528: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Le dossier '/content/drive/MyDrive/CC2-LLM/CHROMA_db' a été trouvé.
# /content/drive/MyDrive/CC2-LLM/functions.py:52: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   db_all = Chroma(persist_directory=CHROMA_DB_PATH, embedding_function=embedding_function)
# Le dossier Chroma contient 142 documents.
# ################## QnA Relevent Docs##################
# [Document(metadata={'content_type': 'text/html;charset=UTF-8', 'description': '', 'language': 'fr', 'source': 'https://fst-informatique.univ-lyon1.fr/departement/scolarite', 'title': 'Scolarité - Département Informatique'}, page_content="Qui contacter pour les questions relatives à la scolarité en licence informatique ?\nOù puis-je trouver des informations sur les inscriptions et la scolarité à l'université Lyon 1 ?\n: 33 4 26 23 44 33\n\xa0\nPour toute question relatique à la scolarité en licence informatique\nmerci de prendre contact avec le service scolarité de la licence\nPour les inscriptions administratives et pédagogiques en licence,\nmerci de consulter les procédures sur site de la FST\n\xa0\nScolarité du master\nScolarite.Informatique@univ-lyon1.fr\nSarra HANACHI\nTél. : 33 4 72 44 83 09\nFoire aux questions\nA qui m'adresser lorsque je suis en licence ? Scolarité de la licence : Quai 43 - bureau 117 - portail Maths-info, tél : 04\xa026 23 44 38\nOù retirer ma carte d'étudiant ? Après l'inscription administrative, le retrait de la carte se fait au\xa0bâtiment ASTREE bureau du BVE. voir le plan. Que faire en cas de perte de ma carte ? S'adresser au service\xa0des cartes étudiants au\xa0bâtiment ASTREE bureau du BVE. voir le plan. Demande de transfert si je quitte LYON1 ? Vous devez contacter le service de scolarité de votre département. Voies et délais de recours ? Voir le fichier\n\xa0\nPlus d'information sur les inscriptions et la scolarité:\nhttps://www.univ-lyon1.fr/formation/inscription-et-scolarite\n\xa0\nDépartement Organisation et contactsScolaritéAccès et plansActualités\nFormation LicencesMastersFormation continueInternationalPlates-formesCellule concoursCandidaturesCertifications\nRelations entreprises Rencontres Etudiants-EntreprisesTaxe d'apprentissage\nLaboratoires\nIntranet\nContact\nAccès et plans\nMentions légales\nAccessibilité : non conforme\nFacebook\nTwitter\nYoutube\nInstagram\nRSS\nhttps://fst-informatique.univ-lyon1.fr/departement/scolarite\nMODE LECTURE\xa0\nHaut de la page\nLe javascript est désactivé sur votre navigateur web et le site de l'université Claude Bernard Lyon 1 risque de ne pas fonctionner correctement.Pour une navigation optimale, merci d'activer le javascript dans les paramètres de votre navigateur web."), Document(metadata={'content_type': 'text/html;charset=UTF-8', 'description': '', 'language': 'fr', 'source': 'https://fst-informatique.univ-lyon1.fr/formation/formation-continue', 'title': 'Formation Continue - Département Informatique'}, page_content="Quelles sont les différentes formations proposées par le département informatique dans le cadre de la formation continue ?\nQuelles sont les conditions et les possibilités offertes par la validation des acquis de l'expérience (VAE) pour accéder à une formation diplômante ou obtenir un diplôme ?\nFormation continue\nTous les diplômes de bac 3 à bac 5 proposés par le département informatique sont accessibles au public en reprise d’études, soit par la formation continue, soit par la validation des acquis de l’expérience (VAE). Contacts\nResponsable\nCatherine Guidarelli\nTél. : 33 4 72 43 13 60\nSecrétariat\nCarine VALVERDE\nTél. : 33 4 72 43 13 60\nService universitaire\nfocal.univ-lyon1.fr\nPlus d'informations\ntravail-emploi.gouv.fr\nvosdroits.service-public.fr\nFormation en alternance\nLa première année de master (M1 informatique), commune à tous les parcours, est possible en alternance. La deuxième année de master (M2 informatique) parcours Technologies de l'Information et Web (TIW) est possible en alternance dans le cadre d'un contrat d'apprentissage et de professionnalisation. La deuxième année de master (M2 informatique) parcours Systèmes, Réseaux et Sécurité (SRS) est possible en alternance, dans le cadre d'un contrat d'apprentissage ou d'un contrat de professionnalisation. La première année de master (M1 IMST), parcours Informatique et Médiation scientifique et technique (IMST) est possible en alternance. La deuxième anné ...
# ################################################
# ***************************** messages [HumanMessage(content='université claude bernard lyon 1', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_v00c', 'function': {'arguments': '{"question": "université claude bernard lyon 1"}', 'name': 'generate_answer'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 486, 'total_tokens': 510, 'completion_time': 0.087272727, 'prompt_time': 0.056735813, 'queue_time': 0.01996663199999999, 'total_time': 0.14400854}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_4e32347616', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7c9cbd39-8f62-441a-83b9-a03c6380e473-0', tool_calls=[{'name': 'generate_answer', 'args': {'question': 'université claude bernard lyon 1'}, 'id': 'call_v00c', 'type': 'tool_call'}], usage_metadata={'input_tokens': 486, 'output_tokens': 24, 'total_tokens': 510}), ToolMessage(content='content="L\'université Claude Bernard Lyon 1 est une université française située à Lyon, qui propose diverses formations et ressources pour les étudiants, notamment en informatique. Le site web de l\'université offre des informations sur les formations, les inscriptions, la scolarité, les relations entreprises, ainsi que des ressources pour les étudiants et les entreprises.\\n\\nPour plus d\'informations, veuillez consulter https://www.univ-lyon1.fr/" additional_kwargs={} response_metadata={\'token_usage\': {\'completion_tokens\': 104, \'prompt_tokens\': 2097, \'total_tokens\': 2201, \'completion_time\': 0.378181818, \'prompt_time\': 0.221132983, \'queue_time\': 0.231539328, \'total_time\': 0.599314801}, \'model_name\': \'llama-3.3-70b-versatile\', \'system_fingerprint\': \'fp_4e32347616\', \'finish_reason\': \'stop\', \'logprobs\': None} id=\'run-b2b93eef-a2d0-4d7a-8431-4a8f959b5486-0\' usage_metadata={\'input_tokens\': 2097, \'output_tokens\': 104, \'total_tokens\': 2201}', tool_call_id='call_v00c')]
# **********************************************
# This issssssss the final response!! L'université Claude Bernard Lyon 1 est une université française située à Lyon, qui propose diverses formations et ressources pour les étudiants, notamment en informatique. Le site web de l'université offre des informations sur les formations, les inscriptions, la scolarité, les relations entreprises, ainsi que des ressources pour les étudiants et les entreprises.
#
# Pour plus d'informations, veuillez consulter https://www.univ-lyon1.fr/
# This is the response :  L'université Claude Bernard Lyon 1 est une université française située à Lyon, qui propose diverses formations et ressources pour les étudiants, notamment en informatique. Le site web de l'université offre des informations sur les formations, les inscriptions, la scolarité, les relations entreprises, ainsi que des ressources pour les étudiants et les entreprises.
#
# Pour plus d'informations, veuillez consulter https://www.univ-lyon1.fr/
# 2025-01-11 17:36:42.196 Examining the path of torch.classes raised: Tried to instantiate class '__path__._path', but it does not exist! Ensure that it is registered via torch::class_
# Le dossier '/content/drive/MyDrive/CC2-LLM/CHROMA_db' a été trouvé.
# Le dossier Chroma contient 142 documents.
# ################## QnA Relevent Docs##################
# [Document(metadata={'content_type': 'text/html', 'description': 'La spécialité M2 IA (Intelligence Artificielle) du Master Informatique de l&apos;Université Claude Bernard Lyon 1 s&apos;adresse à tous les étudiants d&apos;Informatique qui souhaitent se spécialiser dans les techniques les plus avancées de la modélisation et de l&apos;ingénierie des systèmes intelligents et de la décision. Elle offre un socle de connaissances et de compétences permettant de préparer les étudiants aux métiers de la recherche, de la recherche &amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp; développement et de l&apos;innovation dans ce domaine.', 'language': 'fr', 'source': 'http://master-info.univ-lyon1.fr/IA/', 'title': 'Master en Informatique  :  M2 Intelligence Artificielle - Université Claude Bernard Lyon 1'}, page_content="Quelles sont les différentes sources où l'on peut trouver des offres de stage en recherche, notamment dans le domaine de l'intelligence artificielle ?\nComment peut-on proposer un sujet de stage pour les étudiants du M2 IA et quelles sont les étapes à suivre pour y parvenir ?\nERIC : Équipe de Recherche en Ingénierie des Connaissances. CITI : Centre d'Innovations en Télécommunications & Intégration de services. LIP : Laboratoire de l'Informatique du Parallélisme. Les offres de stage du laboratoire LIRIS sont disponibles sur https://liris.cnrs.fr/emplois/offres-de-stage. Les offres de stage dont nous avons connaissance (majoritairement recherche mais pas exclusivement) sont déposées au fil de l'eau sur Tomuss. Vous pouvez aussi regarder sur les différents GDR (groupes de recherche) et réseaux suivants (liste non exhaustive) et vous abonnez à leur liste de diffusion (il y a régulièrement des offres de stages qui sont publiées, plutôt orienté recherche) :\nGDR IA\nGDR Robotique\nGDR Information Signal Image Vision\nGDR Information, Interaction, Intelligence\nRelais d'Information sur les Sciences de la Cognition\nAxe IA & Apprentissage automatique de la FIL\nCommunauté Ingénierie des Connaissances\nCommunauté IA & Éducation\n\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*PAGE\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\\*\n### Proposer un sujet de stage\nSi vous souhaitez proposer un sujet de stage pour les étudiants du M2 IA :\nSi vous êtes enseignant.e d'un établissement public français d'enseignement supérieur, vous devez :\nVous rendre sur cette page pour accéder à la table Tomuss de dépôt des sujets. Si vous avez besoin d'un accès à à Tomuss-fr vous pouvez envoyer un mail à eliane.perna [at] univ-lyon1.fr."), Document(metadata={'description': 'Le département informatique de l&apos;Université Claude Bernard Lyon 1 propose une licence informatique comportant quatre parcours. L&apos;objectif principal de cette licence est d&apos;assurer en 3 ans une formation généraliste en informatique et de former des professionnels dans le domaine de l&apos;Informatique. Cette formation est une bonne base pour continuer en Master, ce que fait une grande majorité des étudiants diplômés.', 'language': 'fr', 'source': 'http://licence-info.univ-lyon1.fr/', 'title': 'Licence informatique - Université Claude Bernard Lyon 1'}, page_content="Quels sont les principaux parcours proposés dans la licence d'informatique et quels sont leurs objectifs ?\nQuelles sont les Unités d'Enseignement (UE) spécifiques proposées dans la licence d'informatique et comment sont-elles organisées ?\nLa L1 commune avec la licence de mathématique comporte autant de mathématiques que d'informatique, puis la L2 et L3 sont constituées très majoritairement d'UE d'informatiques. ## Parcours Bio-Informatique\nLe parcours Bio-informatique s’inscrit dans une perspective interdisciplinaire associant le domaine de la Biologie et de l’Informatique. Il permet d’acquérir les conc ...
# ################################################
# ***************************** messages [HumanMessage(content='Quels sont les UEs de la formation M2 intelligence artificielle?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_yank', 'function': {'arguments': '{"question": "Quels sont les UEs de la formation M2 intelligence artificielle?"}', 'name': 'generate_answer'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 493, 'total_tokens': 523, 'completion_time': 0.109090909, 'prompt_time': 0.065079704, 'queue_time': 0.018287966000000003, 'total_time': 0.174170613}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_4e32347616', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-800600a0-dc17-4e4f-890d-654f601dbd90-0', tool_calls=[{'name': 'generate_answer', 'args': {'question': 'Quels sont les UEs de la formation M2 intelligence artificielle?'}, 'id': 'call_yank', 'type': 'tool_call'}], usage_metadata={'input_tokens': 493, 'output_tokens': 30, 'total_tokens': 523}), ToolMessage(content='content="Les UEs de la formation M2 intelligence artificielle ne sont pas explicitement détaillées dans le contexte fourni. Cependant, il est mentionné que les offres de stage du laboratoire LIRIS sont disponibles sur https://liris.cnrs.fr/emplois/offres-de-stage et que les étudiants peuvent consulter les différents GDR (groupes de recherche) et réseaux pour trouver des offres de stages.\\n\\nPour plus d\'informations, veuillez consulter http://master-info.univ-lyon1.fr/IA/" additional_kwargs={} response_metadata={\'token_usage\': {\'completion_tokens\': 124, \'prompt_tokens\': 3693, \'total_tokens\': 3817, \'completion_time\': 0.450909091, \'prompt_time\': 0.412782074, \'queue_time\': 0.019842269000000023, \'total_time\': 0.863691165}, \'model_name\': \'llama-3.3-70b-versatile\', \'system_fingerprint\': \'fp_4e32347616\', \'finish_reason\': \'stop\', \'logprobs\': None} id=\'run-240a29c1-9c06-4268-afe6-0d70d2481ac7-0\' usage_metadata={\'input_tokens\': 3693, \'output_tokens\': 124, \'total_tokens\': 3817}', tool_call_id='call_yank')]
# **********************************************
# This issssssss the final response!! Les UEs de la formation M2 intelligence artificielle ne sont pas explicitement détaillées dans le contexte fourni. Cependant, il est mentionné que les offres de stage du laboratoire LIRIS sont disponibles sur https://liris.cnrs.fr/emplois/offres-de-stage et que les étudiants peuvent consulter les différents GDR (groupes de recherche) et réseaux pour trouver des offres de stages.
#
# Pour plus d'informations, veuillez consulter http://master-info.univ-lyon1.fr/IA/
# This is the response :  Les UEs de la formation M2 intelligence artificielle ne sont pas explicitement détaillées dans le contexte fourni. Cependant, il est mentionné que les offres de stage du laboratoire LIRIS sont disponibles sur https://liris.cnrs.fr/emplois/offres-de-stage et que les étudiants peuvent consulter les différents GDR (groupes de recherche) et réseaux pour trouver des offres de stages.
#
# Pour plus d'informations, veuillez consulter http://master-info.univ-lyon1.fr/IA/
# Le dossier '/content/drive/MyDrive/CC2-LLM/CHROMA_db' a été trouvé.
# Le dossier Chroma contient 142 documents.
# ################## QnA Relevent Docs##################
# [Document(metadata={'description': "Toutes les formations du département d'Informatique sont adossées à la recherche", 'language': 'fr', 'source': 'https://fst-informatique.univ-lyon1.fr/laboratoires', 'title': 'Les laboratoires de recherche au département informatique - Département Informatique'}, page_content="Quels sont les laboratoires de recherche associés au département informatique ?\nQuelle est la relation entre les formations proposées par le département d'Informatique et la recherche ?\nLes laboratoires de recherche au département informatique - Département Informatique\nAccès direct au contenu\nAccès direct aux informations complémenaires du contenu\nAccès direct au menu principal\nAccès direct au moteur de recherche\nAccès direct au fil d'ariane\nAccès direct au plan du site\nAccès direct aux autres sites web de l'Université\nAccès direct aux outils de l'Université\nActiver le mode contrasté\nActiver la police Open-Dyslexic pour faciliter la lecture des dyslexiques\nActiver le mode lecture zen pour afficher uniquement le contenu\nFacultés - Ecoles - Instituts\nSANTÉFaculté de Médecine Lyon EstFaculté de Médecine et de Maïeutique Lyon Sud - Charles MérieuxFaculté d'OdontologieInstitut des Sciences et Techniques de RéadaptationInstitut des Sciences Pharmaceutiques et BiologiquesSCIENCES ET TECHNOLOGIESInstitut national supérieur du professorat et de l'éducationInstitut Universitaire de Technologie Lyon 1Institut de Science Financière et d'AssurancesObservatoire de LyonPolytech LyonUFR STAPS (Sciences et Techniques des Activités Physiques et Sportives)UFR FS (Chimie, Mathématique, Physique)UFR Biosciences (Biologie, Biochimie)GEP (Génie Electrique des Procédés - Département composante)Informatique (Département Composante)Mécanique (Département Composante)Fermer\nRessources & outils\nRESSOURCESPortail LycéenPortail étudiantBibliothèqueOrientation et insertionSciences pour TousPodcast Sciences en RécitsOffre de formationsCONTACTSAnnuaireDirections et servicesEntités de recherchePlan et accèsOUTILSIntranet des personnelsMoodleEmploi du tempsMessagerieStage et emploiPortefeuille d'Expériences et de CompétencesFermer\nSe connecter\nMenu\nDépartement\nDécouvrir le département\nFermer\nOrganisation et contacts Scolarité Accès et plans Actualités\nFormation\nL'ensemble de l'offre de formation\nFermer\nLicence Master Formation continue International Plates-formes Concours Candidatures Certifications\nRelations entreprises\nContacts des relations entreprises\nFermer\nRencontres Etudiants-Entreprises Taxe apprentissage\nLaboratoires\nIntranet\nfr\nRechercher\nVous êtes ici\xa0:\xa0Informatique → Recherche\nLes laboratoires de recherche au département informatique\nToutes les formations du département d'Informatique sont adossées à la recherche : les enseignements sont majoritairement assurés par des enseignants-chercheurs effectuant leurs travaux de recherche dans les laboratoires de recherche LIRIS, Elico, LIP ou ERIC. Ces laboratoires accueillent également les stagiaires des masters recherche ainsi que les doctorants."), Document(metadata={'content_type': 'text/html;charset=UTF-8', 'description': '', 'language': 'fr', 'source': 'https://fst-informatique.univ-lyon1.fr/relations-entreprises/rencontres-etudiants-entreprises', 'title': 'Rencontres Étudiants-Entreprises - Département Informatique'}, page_content="Quelles sont les Rencontres Étudiants-Entreprises organisées par le département Informatique ?\nQuel est l'objectif principal de ces Rencontres Étudiants-Entreprises ?\nRencontres Étudiants-Entreprises - Département Informatique\nAccès direct au contenu\nAccès direct aux informations complémenaires du contenu\nAccès direct au menu principal\nAccès direct au moteur de recherche\nAccès direct au fil d'ariane\nAccès direct au plan du site\nAccès direct aux autres sites web de l'Université\nAccès direct aux outils de l'Université\nActiver le mode contrasté\nActiver la police Open-Dyslexic pour faciliter la lecture des dyslexiq ...
# ################################################
# ***************************** messages [HumanMessage(content='Quels sont les laboratoires de recherches liés au département informatique?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_jprc', 'function': {'arguments': '{"question": "Quels sont les laboratoires de recherches li\\u00e9s au d\\u00e9partement informatique?"}', 'name': 'generate_answer'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 40, 'prompt_tokens': 494, 'total_tokens': 534, 'completion_time': 0.200279707, 'prompt_time': 0.080823587, 'queue_time': 0.017562772000000004, 'total_time': 0.281103294}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c0cfa69934', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-d98eaf5b-45e2-4727-a402-7f50df724a7c-0', tool_calls=[{'name': 'generate_answer', 'args': {'question': 'Quels sont les laboratoires de recherches liés au département informatique?'}, 'id': 'call_jprc', 'type': 'tool_call'}], usage_metadata={'input_tokens': 494, 'output_tokens': 40, 'total_tokens': 534}), ToolMessage(content='content="Les laboratoires de recherche associés au département informatique sont LIRIS, Elico, LIP et ERIC. Ces laboratoires accueillent les stagiaires des masters recherche ainsi que les doctorants et sont également les lieux où les enseignants-chercheurs effectuent leurs travaux de recherche. \\nPour plus d\'informations, veuillez consulter https://fst-informatique.univ-lyon1.fr/laboratoires." additional_kwargs={} response_metadata={\'token_usage\': {\'completion_tokens\': 101, \'prompt_tokens\': 2647, \'total_tokens\': 2748, \'completion_time\': 0.367272727, \'prompt_time\': 0.260337633, \'queue_time\': 0.028825257999999965, \'total_time\': 0.62761036}, \'model_name\': \'llama-3.3-70b-versatile\', \'system_fingerprint\': \'fp_4196e754db\', \'finish_reason\': \'stop\', \'logprobs\': None} id=\'run-f82c3198-38df-4f0f-8f32-a46a51f278f8-0\' usage_metadata={\'input_tokens\': 2647, \'output_tokens\': 101, \'total_tokens\': 2748}', tool_call_id='call_jprc')]
# **********************************************
# This issssssss the final response!! Les laboratoires de recherche associés au département informatique sont LIRIS, Elico, LIP et ERIC. Ces laboratoires accueillent les stagiaires des masters recherche ainsi que les doctorants et sont également les lieux où les enseignants-chercheurs effectuent leurs travaux de recherche.
# Pour plus d'informations, veuillez consulter https://fst-informatique.univ-lyon1.fr/laboratoires.
# This is the response :  Les laboratoires de recherche associés au département informatique sont LIRIS, Elico, LIP et ERIC. Ces laboratoires accueillent les stagiaires des masters recherche ainsi que les doctorants et sont également les lieux où les enseignants-chercheurs effectuent leurs travaux de recherche.
# Pour plus d'informations, veuillez consulter https://fst-informatique.univ-lyon1.fr/laboratoires.
# Le dossier '/content/drive/MyDrive/CC2-LLM/CHROMA_db' a été trouvé.
# Le dossier Chroma contient 142 documents.
# ################## QnA Relevent Docs##################
# [Document(metadata={'content_type': 'text/html', 'description': 'La spécialité M2 IA (Intelligence Artificielle) du Master Informatique de l&apos;Université Claude Bernard Lyon 1 s&apos;adresse à tous les étudiants d&apos;Informatique qui souhaitent se spécialiser dans les techniques les plus avancées de la modélisation et de l&apos;ingénierie des systèmes intelligents et de la décision. Elle offre un socle de connaissances et de compétences permettant de préparer les étudiants aux métiers de la recherche, de la recherche &amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp; développement et de l&apos;innovation dans ce domaine.', 'language': 'fr', 'source': 'http://master-info.univ-lyon1.fr/IA/', 'title': 'Master en Informatique  :  M2 Intelligence Artificielle - Université Claude Bernard Lyon 1'}, page_content='Quels sont les différents blocs de formation proposés dans le cadre du master en intelligence artificielle ?\nQuelles sont les options et les unités d\'enseignement disponibles pour les étudiants en double cursus ou en master 2 en intelligence artificielle ?\nBloc "Fondamentaux de l\'IA" (12 ECTS)\nIA-AIC (INF2346M) - Artificial Intelligence and Cognition (3 ECTS)\nResponsable : Marie Lefevre (marie.lefevre [at] univ-lyon1.fr)\nFiche offre de formation\nIA-DyCo (INF2347M) - Dynamique des Connaissances (3 ECTS)\nResponsable : Bruno Yun (bruno.yun [at] univ-lyon1.fr)\nFiche offre de formation\nIA-IA (INF2512M) - Intelligent Agents (3 ECTS)\nResponsable : Laëtitia Matignon (laetitia.matignon [at] univ-lyon1.fr)\nFiche offre de formation\nIA-Graphes (INF2352M) - Graphes, Complexité, Combinatoire (3 ECTS)\nResponsable : Samba Ndojh Ndiaye (samba-ndojh.ndiaye [at] univ-lyon1.fr)\nFiche offre de formation\nBloc "Machine Learning and Knowledge Discovery from Data" (9 ECTS)\nIA-BIML (INF2483M) - Bio-Inspired Machine Learning (3 ECTS)\nResponsable : Mathieu Lefort (mathieu.lefort [at] univ-lyon1.fr)\nFiche offre de formation\nDS-DataMining (INF2355M) - Data Mining (3 ECTS)\nResponsable : Remy Cazabet (remy.cazabet [at] univ-lyon1.fr)\nFiche offre de formation\nIA-TAA (INF2417M) - Techniques d\'apprentissage automatique (3 ECTS)\nResponsable : Haytham Elghazel (haytham.elghazel [at] univ-lyon1.fr) et Khalid Benabdeslem (khalid.benabdeslem [at] univ-lyon1.fr)\nFiche offre de formation\nBloc "Options " (9 ECTS)\n3 options à choisir parmi :\nIM-TC-App (INF2335) - Apprentissage Profond et Image (3 ECTS)\nResponsable : Alexandre Meyer (alexandre.meyer [at] univ-lyon1.fr)\nFiche offre de formation\nIA-AI4IoTR (INF2485M) - Artificial Intelligence for Internet of Things and Robotics (3 ECTS)\nResponsable : Laëtitia Matignon (laetitia.matignon [at] univ-lyon1.fr)\nFiche offre de formation\nIA-EIAH (INF2351M) - Environnements Informatiques pour l\'Apprentissage Humain (3 ECTS)\nResponsable : Marie Lefevre (marie.lefevre [at] univ-lyon1.fr)\nFiche offre de formation\nIA-LLM (INF2511M) - Theory and Practical Applications of Large Language Models (3 ECTS)\nResponsable : Bruno Yun (bruno.yun [at] univ-lyon1.fr)\nFiche offre de formation\nDS-DataVisu (INF2353M) - Data Visualization (3 ECTS)\nResponsable : Aurélien Tabard (aurelien.tabard [at] univ-lyon1.fr)\nFiche offre de formation\nIA-IHM&IA (INF2486M) - Intelligence Artificielle et Interaction Humain Machine (3 ECTS)\nUE non ouverte en 2024-25\nResponsable : Aurélien Tabard (aurelien.tabard [at] univ-lyon1.fr)\nDISS-ROB (UCIF212M) - Robotic Modeling and Control (3 ECTS)\nUE non ouverte en 2024-25\nResponsable : Liming Chen (liming.chen [at] univ-lyon1.fr)\nBloc "Soft Skils" (9 ECTS)\nINFO-Droit (INF2014M) - Droit de l\'informatique et de l\'Internet (3 ECTS)\nResponsable : Yann Bergheaud\nFiche offre de formation\nINFO-Métier (INF2178M) - Connaissance métier (3 ECTS)\nResponsable : Marie Lefevre (marie.lefevre [at] univ-lyon1.fr) et Mathieu Lefort (mathieu.lefort [at] univ-lyo ...
# ################################################
# ***************************** messages [HumanMessage(content='Quel est le programme du master 2 intelligence artifcielle?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_yrdj', 'function': {'arguments': '{"question": "Quel est le programme du master 2 intelligence artificielle?"}', 'name': 'generate_answer'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 491, 'total_tokens': 519, 'completion_time': 0.101818182, 'prompt_time': 0.054249767, 'queue_time': 0.020927828000000002, 'total_time': 0.156067949}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_4e32347616', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-70d8a870-53d3-4a6a-b80c-8de3b9a594f2-0', tool_calls=[{'name': 'generate_answer', 'args': {'question': 'Quel est le programme du master 2 intelligence artificielle?'}, 'id': 'call_yrdj', 'type': 'tool_call'}], usage_metadata={'input_tokens': 491, 'output_tokens': 28, 'total_tokens': 519}), ToolMessage(content='content=\'Le programme du master 2 intelligence artificielle de l\\\'Université Claude Bernard Lyon 1 est divisé en plusieurs blocs de formation, notamment :\\n\\n- Le bloc "Fondamentaux de l\\\'IA" qui comprend des unités d\\\'enseignement telles que l\\\'intelligence artificielle et la cognition, la dynamique des connaissances, les agents intelligents, les graphes, la complexité et la combinatoire.\\n- Le bloc "Machine Learning and Knowledge Discovery from Data" qui inclut des unités d\\\'enseignement telles que le machine learning bio-inspiré, la fouille de données, les techniques d\\\'apprentissage automatique.\\n- Le bloc "Options" qui propose différentes unités d\\\'enseignement telles que l\\\'apprentissage profond et l\\\'image, l\\\'intelligence artificielle pour l\\\'Internet des objets et la robotique, les environnements informatiques pour l\\\'apprentissage humain, la théorie et les applications des grands modèles de langage, la visualisation de données, l\\\'intelligence artificielle et l\\\'interaction humain-machine.\\n- Le bloc "Soft Skils" qui comprend des unités d\\\'enseignement telles que le droit de l\\\'informatique et de l\\\'Internet, la connaissance métier, l\\\'anglais pour la communication professionnelle.\\n- Le bloc "Stage" qui inclut un stage d\\\'application professionnelle ou de recherche.\\n\\nPour plus d\\\'informations, veuillez consulter http://master-info.univ-lyon1.fr/IA/\' additional_kwargs={} response_metadata={\'token_usage\': {\'completion_tokens\': 341, \'prompt_tokens\': 5720, \'total_tokens\': 6061, \'completion_time\': 1.24, \'prompt_time\': 0.65188436, \'queue_time\': 0.30788727699999996, \'total_time\': 1.8918843600000002}, \'model_name\': \'llama-3.3-70b-versatile\', \'system_fingerprint\': \'fp_4196e754db\', \'finish_reason\': \'stop\', \'logprobs\': None} id=\'run-bd8cb06e-9b65-4b8b-9dd3-f301a44c7f8f-0\' usage_metadata={\'input_tokens\': 5720, \'output_tokens\': 341, \'total_tokens\': 6061}', tool_call_id='call_yrdj')]
# **********************************************
# This issssssss the final response!! Le programme du master 2 intelligence artificielle de l'Université Claude Bernard Lyon 1 est divisé en plusieurs blocs de formation, notamment :
#
# - Le bloc "Fondamentaux de l'IA" qui comprend des unités d'enseignement telles que l'intelligence artificielle et la cognition, la dynamique des connaissances, les agents intelligents, les graphes, la complexité et la combinatoire.
# - Le bloc "Machine Learning and Knowledge Discovery from Data" qui inclut des unités d'enseignement telles que le machine learning bio-inspiré, la fouille de données, les techniques d'apprentissage automatique.
# - Le bloc "Options" qui propose différentes unités d'enseignement telles que l'apprentissage profond et l'image, l'intelligence artificielle pour l'Internet des objets et la robotique, les environnements informatiques pour l'apprentissage humain, la théorie et les applications des grands modèles de langage, la visualisation de données, l'intelligence artificielle et l'interaction humain-machine.
# - Le bloc "Soft Skils" qui comprend des unités d'enseignement telles que le droit de l'informatique et de l'Internet, la connaissance métier, l'anglais pour la communication professionnelle.
# - Le bloc "Stage" qui inclut un stage d'application professionnelle ou de recherche.
#
# Pour plus d'informations, veuillez consulter http://master-info.univ-lyon1.fr/IA/
# This is the response :  Le programme du master 2 intelligence artificielle de l'Université Claude Bernard Lyon 1 est divisé en plusieurs blocs de formation, notamment :
#
# - Le bloc "Fondamentaux de l'IA" qui comprend des unités d'enseignement telles que l'intelligence artificielle et la cognition, la dynamique des connaissances, les agents intelligents, les graphes, la complexité et la combinatoire.
# - Le bloc "Machine Learning and Knowledge Discovery from Data" qui inclut des unités d'enseignement telles que le machine learning bio-inspiré, la fouille de données, les techniques d'apprentissage automatique.
# - Le bloc "Options" qui propose différentes unités d'enseignement telles que l'apprentissage profond et l'image, l'intelligence artificielle pour l'Internet des objets et la robotique, les environnements informatiques pour l'apprentissage humain, la théorie et les applications des grands modèles de langage, la visualisation de données, l'intelligence artificielle et l'interaction humain-machine.
# - Le bloc "Soft Skils" qui comprend des unités d'enseignement telles que le droit de l'informatique et de l'Internet, la connaissance métier, l'anglais pour la communication professionnelle.
# - Le bloc "Stage" qui inclut un stage d'application professionnelle ou de recherche.
#
# Pour plus d'informations, veuillez consulter http://master-info.univ-lyon1.fr/IA/
# Le dossier '/content/drive/MyDrive/CC2-LLM/CHROMA_db' a été trouvé.
# Le dossier Chroma contient 142 documents.
# ################## QnA Relevent Docs##################
# [Document(metadata={'content_type': 'text/html', 'description': 'La spécialité M2 IA (Intelligence Artificielle) du Master Informatique de l&apos;Université Claude Bernard Lyon 1 s&apos;adresse à tous les étudiants d&apos;Informatique qui souhaitent se spécialiser dans les techniques les plus avancées de la modélisation et de l&apos;ingénierie des systèmes intelligents et de la décision. Elle offre un socle de connaissances et de compétences permettant de préparer les étudiants aux métiers de la recherche, de la recherche &amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp; développement et de l&apos;innovation dans ce domaine.', 'language': 'fr', 'source': 'http://master-info.univ-lyon1.fr/IA/', 'title': 'Master en Informatique  :  M2 Intelligence Artificielle - Université Claude Bernard Lyon 1'}, page_content='Quels sont les différents blocs de formation proposés dans le cadre du master en intelligence artificielle ?\nQuelles sont les options et les unités d\'enseignement disponibles pour les étudiants en double cursus ou en master 2 en intelligence artificielle ?\nBloc "Fondamentaux de l\'IA" (12 ECTS)\nIA-AIC (INF2346M) - Artificial Intelligence and Cognition (3 ECTS)\nResponsable : Marie Lefevre (marie.lefevre [at] univ-lyon1.fr)\nFiche offre de formation\nIA-DyCo (INF2347M) - Dynamique des Connaissances (3 ECTS)\nResponsable : Bruno Yun (bruno.yun [at] univ-lyon1.fr)\nFiche offre de formation\nIA-IA (INF2512M) - Intelligent Agents (3 ECTS)\nResponsable : Laëtitia Matignon (laetitia.matignon [at] univ-lyon1.fr)\nFiche offre de formation\nIA-Graphes (INF2352M) - Graphes, Complexité, Combinatoire (3 ECTS)\nResponsable : Samba Ndojh Ndiaye (samba-ndojh.ndiaye [at] univ-lyon1.fr)\nFiche offre de formation\nBloc "Machine Learning and Knowledge Discovery from Data" (9 ECTS)\nIA-BIML (INF2483M) - Bio-Inspired Machine Learning (3 ECTS)\nResponsable : Mathieu Lefort (mathieu.lefort [at] univ-lyon1.fr)\nFiche offre de formation\nDS-DataMining (INF2355M) - Data Mining (3 ECTS)\nResponsable : Remy Cazabet (remy.cazabet [at] univ-lyon1.fr)\nFiche offre de formation\nIA-TAA (INF2417M) - Techniques d\'apprentissage automatique (3 ECTS)\nResponsable : Haytham Elghazel (haytham.elghazel [at] univ-lyon1.fr) et Khalid Benabdeslem (khalid.benabdeslem [at] univ-lyon1.fr)\nFiche offre de formation\nBloc "Options " (9 ECTS)\n3 options à choisir parmi :\nIM-TC-App (INF2335) - Apprentissage Profond et Image (3 ECTS)\nResponsable : Alexandre Meyer (alexandre.meyer [at] univ-lyon1.fr)\nFiche offre de formation\nIA-AI4IoTR (INF2485M) - Artificial Intelligence for Internet of Things and Robotics (3 ECTS)\nResponsable : Laëtitia Matignon (laetitia.matignon [at] univ-lyon1.fr)\nFiche offre de formation\nIA-EIAH (INF2351M) - Environnements Informatiques pour l\'Apprentissage Humain (3 ECTS)\nResponsable : Marie Lefevre (marie.lefevre [at] univ-lyon1.fr)\nFiche offre de formation\nIA-LLM (INF2511M) - Theory and Practical Applications of Large Language Models (3 ECTS)\nResponsable : Bruno Yun (bruno.yun [at] univ-lyon1.fr)\nFiche offre de formation\nDS-DataVisu (INF2353M) - Data Visualization (3 ECTS)\nResponsable : Aurélien Tabard (aurelien.tabard [at] univ-lyon1.fr)\nFiche offre de formation\nIA-IHM&IA (INF2486M) - Intelligence Artificielle et Interaction Humain Machine (3 ECTS)\nUE non ouverte en 2024-25\nResponsable : Aurélien Tabard (aurelien.tabard [at] univ-lyon1.fr)\nDISS-ROB (UCIF212M) - Robotic Modeling and Control (3 ECTS)\nUE non ouverte en 2024-25\nResponsable : Liming Chen (liming.chen [at] univ-lyon1.fr)\nBloc "Soft Skils" (9 ECTS)\nINFO-Droit (INF2014M) - Droit de l\'informatique et de l\'Internet (3 ECTS)\nResponsable : Yann Bergheaud\nFiche offre de formation\nINFO-Métier (INF2178M) - Connaissance métier (3 ECTS)\nResponsable : Marie Lefevre (marie.lefevre [at] univ-lyon1.fr) et Mathieu Lefort (mathieu.lefort [at] univ-lyo ...
# ################################################
# ***************************** messages [HumanMessage(content='Qui est le responsable de la formation Master 2 intelligence artificielle?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_rg6t', 'function': {'arguments': '{"question": "Qui est le responsable de la formation Master 2 intelligence artificielle?"}', 'name': 'generate_answer'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 492, 'total_tokens': 521, 'completion_time': 0.105454545, 'prompt_time': 0.050883178, 'queue_time': 0.028257317000000004, 'total_time': 0.156337723}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_4196e754db', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-48f8cf84-8c2d-4841-8ecc-64b7d00d7d57-0', tool_calls=[{'name': 'generate_answer', 'args': {'question': 'Qui est le responsable de la formation Master 2 intelligence artificielle?'}, 'id': 'call_rg6t', 'type': 'tool_call'}], usage_metadata={'input_tokens': 492, 'output_tokens': 29, 'total_tokens': 521}), ToolMessage(content='content="Le responsable de la formation Master 2 intelligence artificielle n\'est pas explicitement mentionné dans le contexte fourni. Cependant, il est possible de contacter le département informatique de l\'Université Claude Bernard Lyon 1 pour obtenir plus d\'informations sur la formation et son responsable.\\n\\nPour plus d\'informations, veuillez consulter http://master-info.univ-lyon1.fr/IA/" additional_kwargs={} response_metadata={\'token_usage\': {\'completion_tokens\': 94, \'prompt_tokens\': 5721, \'total_tokens\': 5815, \'completion_time\': 0.446818678, \'prompt_time\': 0.999362036, \'queue_time\': 0.03708857600000015, \'total_time\': 1.446180714}, \'model_name\': \'llama-3.3-70b-versatile\', \'system_fingerprint\': \'fp_c0cfa69934\', \'finish_reason\': \'stop\', \'logprobs\': None} id=\'run-a24421cf-b7a4-4f9d-9c10-332c4cce320f-0\' usage_metadata={\'input_tokens\': 5721, \'output_tokens\': 94, \'total_tokens\': 5815}', tool_call_id='call_rg6t')]
# **********************************************
# This issssssss the final response!! Le responsable de la formation Master 2 intelligence artificielle n'est pas explicitement mentionné dans le contexte fourni. Cependant, il est possible de contacter le département informatique de l'Université Claude Bernard Lyon 1 pour obtenir plus d'informations sur la formation et son responsable.
#
# Pour plus d'informations, veuillez consulter http://master-info.univ-lyon1.fr/IA/
# This is the response :  Le responsable de la formation Master 2 intelligence artificielle n'est pas explicitement mentionné dans le contexte fourni. Cependant, il est possible de contacter le département informatique de l'Université Claude Bernard Lyon 1 pour obtenir plus d'informations sur la formation et son responsable.
#
# Pour plus d'informations, veuillez consulter http://master-info.univ-lyon1.fr/IA/
# This is the response :  None
# USER_AGENT existe déjà : MyApp
# Le dossier '/content/drive/MyDrive/CC2-LLM/CHROMA_db' a été trouvé.
# Le dossier Chroma contient 142 documents.
# ################## QnA Relevent Docs##################
# [Document(metadata={'content_type': 'text/html', 'description': 'La spécialité M2 IA (Intelligence Artificielle) du Master Informatique de l&apos;Université Claude Bernard Lyon 1 s&apos;adresse à tous les étudiants d&apos;Informatique qui souhaitent se spécialiser dans les techniques les plus avancées de la modélisation et de l&apos;ingénierie des systèmes intelligents et de la décision. Elle offre un socle de connaissances et de compétences permettant de préparer les étudiants aux métiers de la recherche, de la recherche &amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp; développement et de l&apos;innovation dans ce domaine.', 'language': 'fr', 'source': 'http://master-info.univ-lyon1.fr/IA/', 'title': 'Master en Informatique  :  M2 Intelligence Artificielle - Université Claude Bernard Lyon 1'}, page_content='Quels sont les différents blocs de formation proposés dans le cadre du master en intelligence artificielle ?\nQuelles sont les options et les unités d\'enseignement disponibles pour les étudiants en double cursus ou en master 2 en intelligence artificielle ?\nBloc "Fondamentaux de l\'IA" (12 ECTS)\nIA-AIC (INF2346M) - Artificial Intelligence and Cognition (3 ECTS)\nResponsable : Marie Lefevre (marie.lefevre [at] univ-lyon1.fr)\nFiche offre de formation\nIA-DyCo (INF2347M) - Dynamique des Connaissances (3 ECTS)\nResponsable : Bruno Yun (bruno.yun [at] univ-lyon1.fr)\nFiche offre de formation\nIA-IA (INF2512M) - Intelligent Agents (3 ECTS)\nResponsable : Laëtitia Matignon (laetitia.matignon [at] univ-lyon1.fr)\nFiche offre de formation\nIA-Graphes (INF2352M) - Graphes, Complexité, Combinatoire (3 ECTS)\nResponsable : Samba Ndojh Ndiaye (samba-ndojh.ndiaye [at] univ-lyon1.fr)\nFiche offre de formation\nBloc "Machine Learning and Knowledge Discovery from Data" (9 ECTS)\nIA-BIML (INF2483M) - Bio-Inspired Machine Learning (3 ECTS)\nResponsable : Mathieu Lefort (mathieu.lefort [at] univ-lyon1.fr)\nFiche offre de formation\nDS-DataMining (INF2355M) - Data Mining (3 ECTS)\nResponsable : Remy Cazabet (remy.cazabet [at] univ-lyon1.fr)\nFiche offre de formation\nIA-TAA (INF2417M) - Techniques d\'apprentissage automatique (3 ECTS)\nResponsable : Haytham Elghazel (haytham.elghazel [at] univ-lyon1.fr) et Khalid Benabdeslem (khalid.benabdeslem [at] univ-lyon1.fr)\nFiche offre de formation\nBloc "Options " (9 ECTS)\n3 options à choisir parmi :\nIM-TC-App (INF2335) - Apprentissage Profond et Image (3 ECTS)\nResponsable : Alexandre Meyer (alexandre.meyer [at] univ-lyon1.fr)\nFiche offre de formation\nIA-AI4IoTR (INF2485M) - Artificial Intelligence for Internet of Things and Robotics (3 ECTS)\nResponsable : Laëtitia Matignon (laetitia.matignon [at] univ-lyon1.fr)\nFiche offre de formation\nIA-EIAH (INF2351M) - Environnements Informatiques pour l\'Apprentissage Humain (3 ECTS)\nResponsable : Marie Lefevre (marie.lefevre [at] univ-lyon1.fr)\nFiche offre de formation\nIA-LLM (INF2511M) - Theory and Practical Applications of Large Language Models (3 ECTS)\nResponsable : Bruno Yun (bruno.yun [at] univ-lyon1.fr)\nFiche offre de formation\nDS-DataVisu (INF2353M) - Data Visualization (3 ECTS)\nResponsable : Aurélien Tabard (aurelien.tabard [at] univ-lyon1.fr)\nFiche offre de formation\nIA-IHM&IA (INF2486M) - Intelligence Artificielle et Interaction Humain Machine (3 ECTS)\nUE non ouverte en 2024-25\nResponsable : Aurélien Tabard (aurelien.tabard [at] univ-lyon1.fr)\nDISS-ROB (UCIF212M) - Robotic Modeling and Control (3 ECTS)\nUE non ouverte en 2024-25\nResponsable : Liming Chen (liming.chen [at] univ-lyon1.fr)\nBloc "Soft Skils" (9 ECTS)\nINFO-Droit (INF2014M) - Droit de l\'informatique et de l\'Internet (3 ECTS)\nResponsable : Yann Bergheaud\nFiche offre de formation\nINFO-Métier (INF2178M) - Connaissance métier (3 ECTS)\nResponsable : Marie Lefevre (marie.lefevre [at] univ-lyon1.fr) et Mathieu Lefort (mathieu.lefort [at] univ-lyo ...
# ################################################
# ***************************** messages [HumanMessage(content='qui est le responsable des stages pour la formation master 2 intelligence artificielle?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_w958', 'function': {'arguments': '{"question": "qui est le responsable des stages pour la formation master 2 intelligence artificielle?"}', 'name': 'generate_answer'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 494, 'total_tokens': 525, 'completion_time': 0.112727273, 'prompt_time': 0.057541022, 'queue_time': 0.019337309999999996, 'total_time': 0.170268295}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_4e32347616', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-b5f1bdae-461f-49e0-a978-21fec7314136-0', tool_calls=[{'name': 'generate_answer', 'args': {'question': 'qui est le responsable des stages pour la formation master 2 intelligence artificielle?'}, 'id': 'call_w958', 'type': 'tool_call'}], usage_metadata={'input_tokens': 494, 'output_tokens': 31, 'total_tokens': 525}), ToolMessage(content='content="Le responsable des stages pour la formation Master 2 Intelligence Artificielle est Mathieu Lefort. \\n\\nPour plus d\'informations, veuillez consulter http://master-info.univ-lyon1.fr/IA/" additional_kwargs={} response_metadata={\'token_usage\': {\'completion_tokens\': 50, \'prompt_tokens\': 5723, \'total_tokens\': 5773, \'completion_time\': 0.181818182, \'prompt_time\': 0.634112427, \'queue_time\': 0.05320758799999992, \'total_time\': 0.815930609}, \'model_name\': \'llama-3.3-70b-versatile\', \'system_fingerprint\': \'fp_4196e754db\', \'finish_reason\': \'stop\', \'logprobs\': None} id=\'run-062e097a-46e3-4e91-b79b-4444d2439292-0\' usage_metadata={\'input_tokens\': 5723, \'output_tokens\': 50, \'total_tokens\': 5773}', tool_call_id='call_w958')]
# **********************************************
# This issssssss the final response!! Le responsable des stages pour la formation Master 2 Intelligence Artificielle est Mathieu Lefort.
#
# Pour plus d'informations, veuillez consulter http://master-info.univ-lyon1.fr/IA/
# This is the response :  Le responsable des stages pour la formation Master 2 Intelligence Artificielle est Mathieu Lefort.
#
# Pour plus d'informations, veuillez consulter http://master-info.univ-lyon1.fr/IA/
# ...
# ################################################
# ***************************** messages [HumanMessage(content='qui est marie lefèvre?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_t54p', 'function': {'arguments': '{"question": "Qui est Marie Lefebvre?"}', 'name': 'generate_answer'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 569, 'total_tokens': 590, 'completion_time': 0.028, 'prompt_time': 0.039805418, 'queue_time': 0.018106799, 'total_time': 0.067805418}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f66ccb39ec', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-8076bd8f-4bfa-4c70-84ef-3cfef59dba23-0', tool_calls=[{'name': 'generate_answer', 'args': {'question': 'Qui est Marie Lefebvre?'}, 'id': 'call_t54p', 'type': 'tool_call'}], usage_metadata={'input_tokens': 569, 'output_tokens': 21, 'total_tokens': 590}), ToolMessage(content="content='Je ne dispose pas de cette information.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 5614, 'total_tokens': 5623, 'completion_time': 0.012, 'prompt_time': 0.447933397, 'queue_time': 0.03993616999999999, 'total_time': 0.459933397}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f66ccb39ec', 'finish_reason': 'stop', 'logprobs': None} id='run-6770590b-5491-44fd-95f3-e9436e7d4e5e-0' usage_metadata={'input_tokens': 5614, 'output_tokens': 9, 'total_tokens': 5623}", tool_call_id='call_t54p')]
# **********************************************
# This issssssss the final response!! Je ne dispose pas de cette information.
# This is the response :  Je ne dispose pas de cette information.
# This is the response :  None
# USER_AGENT existe déjà : MyApp
# Le dossier '/content/drive/MyDrive/CC2-LLM/CHROMA_db' a été trouvé.
# Le dossier Chroma contient 142 documents.
# ################## QnA Relevent Docs##################
# [Document(metadata={'description': 'Le département informatique de l&apos;Université Claude Bernard Lyon 1 propose une licence informatique comportant quatre parcours. L&apos;objectif principal de cette licence est d&apos;assurer en 3 ans une formation généraliste en informatique et de former des professionnels dans le domaine de l&apos;Informatique. Cette formation est une bonne base pour continuer en Master, ce que fait une grande majorité des étudiants diplômés.', 'language': 'fr', 'source': 'http://licence-info.univ-lyon1.fr/', 'title': 'Licence informatique - Université Claude Bernard Lyon 1'}, page_content="Quels sont les principaux parcours proposés dans la licence d'informatique et quels sont leurs objectifs ?\nQuelles sont les Unités d'Enseignement (UE) spécifiques proposées dans la licence d'informatique et comment sont-elles organisées ?\nLa L1 commune avec la licence de mathématique comporte autant de mathématiques que d'informatique, puis la L2 et L3 sont constituées très majoritairement d'UE d'informatiques. ## Parcours Bio-Informatique\nLe parcours Bio-informatique s’inscrit dans une perspective interdisciplinaire associant le domaine de la Biologie et de l’Informatique. Il permet d’acquérir les concepts de bases et les outils méthodologiques pour analyser, interpréter des données biologiques puis en extraire des informations pertinentes en vue de la compréhension et de la modélisation des processus impliqués. L’objectif de ce parcours est de fournir une double compétence en biologie comme discipline mineure dans la formation. La discipline majeure reste l'informatique. Il existe un parcours symétrique dans la licence science de la Vie, ou la discipline majeure est la biologie : [le parcours Bio-informatique, statistique et modélisation](https://offre-de-formations.univ-lyon1.fr/front\\_fiche\\_parcours.php?PARCOURS\\_ID=321). Pour le parcours bio-info: en L1, les étudiants suivent la licence commune du portail maths-info avec des UE optionnelles en biologie (biologie et modélisation et génétique). En L2 et L3 certaines UE informatique sont remplacées par des UE biologiques. Plus d'informations : [Parcours Bio-Informatique](http://offre-de-formations.univ-lyon1.fr/parcours-323/bio-informatique.html)\n## Parcours Informatique-Mathématiques\nCe parcours est une variante du parcours informatique pour lequel certaines UE sont remplacées par des UE de mathématiques. Les UE de mathématiques sont suivies avec les étudiants de licence de mathématiques, et ont donc les mêmes exigences que les UE de la licence de mathématiques. Le principal objectif de ce parcours est de fournir une double compétence en mathématiques comme discipline mineure dans la formation. La discipline majeure reste l'informatique, et le débouché principal le master d'informatique. Il existe un parcours symétrique dans la licence de mathématiques : [le parcours mathématiques et informatique](https://offre-de-formations.univ-lyon1.fr/parcours-932/mathematiques-et-informatique.html). L'organisation de la formation est la suivante : en L1, les étudiants suivent la licence commune du portail maths-info. - En L2, les UE [architecture](https://offre-de-formations.univ-lyon1.fr/%2Fue-26134-12%2Farchitecture-des-ordinateurs.html), [programmation fonctionnelle](https://offre-de-formations.univ-lyon1.fr/%2Fue-26078-12%2Fprogrammation-fonctionnelle.html), [statistiques pour l'informatique](https://offre-de-formations.univ-lyon1.fr/%2Fue-16426-12%2Fstatistiques-pour-l%27informatique.html) et [analyse matricielle et algèbre linéaire appliquée A](https://offre-de-formations.univ-lyon1.fr/%2Fue-8211-12%2Fanalyse-matricielle-et-algebre-lineaire-appliquee-a.html) sont remplacées par des UE de mathématiques. - En L3, le projet informatique, les options de L3 informatique et le stage sont remplacées par des UE de mathématiques (il est vivement recommandé de faire un stage volontaire même si le stage n'est pas obligatoire dans le cursus). Plus d'informations : [Parcours ...
# ################################################
# ***************************** messages [HumanMessage(content='quel est le responsable de la formation MASTER 2 data science?\n\n', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_3s8r', 'function': {'arguments': '{"question": "quel est le responsable de la formation MASTER 2 data science?"}', 'name': 'generate_answer'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 573, 'total_tokens': 599, 'completion_time': 0.034666667, 'prompt_time': 0.036571073, 'queue_time': 0.053558196999999995, 'total_time': 0.07123774}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_c5e685ab6f', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-fdbaff85-8711-42e0-b7be-8fa221942925-0', tool_calls=[{'name': 'generate_answer', 'args': {'question': 'quel est le responsable de la formation MASTER 2 data science?'}, 'id': 'call_3s8r', 'type': 'tool_call'}], usage_metadata={'input_tokens': 573, 'output_tokens': 26, 'total_tokens': 599}), ToolMessage(content='content="Je ne dispose pas de cette information. \\n\\nPour plus d\'informations, veuillez consulter http://master-info.univ-lyon1.fr/DS/." additional_kwargs={} response_metadata={\'token_usage\': {\'completion_tokens\': 36, \'prompt_tokens\': 4712, \'total_tokens\': 4748, \'completion_time\': 0.048, \'prompt_time\': 0.295868864, \'queue_time\': 0.10349393000000001, \'total_time\': 0.343868864}, \'model_name\': \'llama-3.1-8b-instant\', \'system_fingerprint\': \'fp_c5e685ab6f\', \'finish_reason\': \'stop\', \'logprobs\': None} id=\'run-b0fa0867-b916-412f-8ee1-46b1f3e01b63-0\' usage_metadata={\'input_tokens\': 4712, \'output_tokens\': 36, \'total_tokens\': 4748}', tool_call_id='call_3s8r')]
# **********************************************
# This issssssss the final response!! Je ne dispose pas de cette information.
#
# Pour plus d'informations, veuillez consulter http://master-info.univ-lyon1.fr/DS/.
# This is the response :  Je ne dispose pas de cette information.
#
# Pour plus d'informations, veuillez consulter http://master-info.univ-lyon1.fr/DS/.
# This is the response :  None
# This is the response :  None
# USER_AGENT existe déjà : MyApp
# Le dossier '/content/drive/MyDrive/CC2-LLM/CHROMA_db' a été trouvé.
# Le dossier Chroma contient 142 documents.
# Le dossier '/content/drive/MyDrive/CC2-LLM/chroma_certif' a été trouvé.
# Le dossier Chroma est vide, aucun document trouvé.
# 2025-01-11 18:07:25.878 Uncaught app execution
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/exec_code.py", line 88, in exec_func_with_error_handling
#     result = func()
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 579, in code_to_exec
#     exec(code, module.__dict__)
#   File "/content/drive/MyDrive/CC2-LLM/app.py", line 44, in <module>
#     response = handle_query(query, llm, tools)
#   File "/content/drive/MyDrive/CC2-LLM/functions.py", line 258, in handle_query
#     tool_output = selected_tool.invoke(tool_call["args"])
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/tools/base.py", line 484, in invoke
#     return self.run(tool_input, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/tools/base.py", line 725, in run
#     raise error_to_raise
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/tools/base.py", line 693, in run
#     response = context.run(self._run, *tool_args, **tool_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/tools/structured.py", line 80, in _run
#     return self.func(*args, **kwargs)
#   File "/content/drive/MyDrive/CC2-LLM/functions.py", line 208, in certif_recommendation
#     response = llm.invoke(prompt_with_context)
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 286, in invoke
#     self.generate_prompt(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 786, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 643, in generate
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 633, in generate
#     self._generate_with_cache(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py", line 851, in _generate_with_cache
#     result = self._generate(
#   File "/usr/local/lib/python3.10/dist-packages/langchain_groq/chat_models.py", line 480, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#   File "/usr/local/lib/python3.10/dist-packages/groq/resources/chat/completions.py", line 316, in create
#     return self._post(
#   File "/usr/local/lib/python3.10/dist-packages/groq/_base_client.py", line 1266, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#   File "/usr/local/lib/python3.10/dist-packages/groq/_base_client.py", line 958, in request
#     return self._request(
#   File "/usr/local/lib/python3.10/dist-packages/groq/_base_client.py", line 1061, in _request
#     raise self._make_status_error_from_response(err.response) from None
# groq.APIStatusError: Error code: 413 - {'error': {'message': 'Request too large for model `llama-3.3-70b-versatile` in organization `org_01jgcwxp8sfh79n857qp4xdn9x` on tokens per minute (TPM): Limit 6000, Requested 8700, please reduce your message size and try again. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
# /root/.npm/_npx/75ac80b86e83d4a2/node_modules/localtunnel/bin/lt.js:81
#     throw err;
#     ^
#
# Error: connection refused: localtunnel.me:12765 (check your firewall settings)
#     at Socket.<anonymous> (/root/.npm/_npx/75ac80b86e83d4a2/node_modules/localtunnel/lib/TunnelCluster.js:52:11)
#     at Socket.emit (node:events:517:28)
#     at emitErrorNT (node:internal/streams/destroy:151:8)
#     at emitErrorCloseNT (node:internal/streams/destroy:116:3)
#     at process.processTicksAndRejections (node:internal/process/task_queues:82:21)
#
# Node.js v18.20.5
# ⠙  Stopping...
